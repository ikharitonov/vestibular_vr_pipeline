# %% [markdown]
# # View GRAB5-HT mismatch closed loop and open loop data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from scipy.stats import pearsonr, spearmanr
from analysis_functions import *
from model_functions import *
import matplotlib.patches as patches
import seaborn as sns

# %%
## Should be updated to be read from session files perhaps
RunTresholdDict = {'B3M1': 145, 'B3M2': 295, 'B3M3': 325, 'B2M4': 110, 'B2M5': 180}

# %%
GRAB_closedopen_1 = pd.read_csv('/Path/To/Session/csvfile.csv'), dtype=dtype_dict)
GRAB_closedopen_2 = pd.read_csv('/Path/To/Session/csvfile.csv'), dtype=dtype_dict)
# Out:
# /var/folders/j0/v9b_1b8d44l7jr8z9bvwrg4h0000gp/T/ipykernel_97006/3979421910.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   GCaMP_Reg_1 = pd.read_csv('/Users/hildeteigen/Downloads/B3M3_G8_MMclosed_session1.csv')#, dtype=dtype_dict)
# /var/folders/j0/v9b_1b8d44l7jr8z9bvwrg4h0000gp/T/ipykernel_97006/3979421910.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   GCaMP_Reg_2 = pd.read_csv('/Users/hildeteigen/Downloads/B3M3_G8_MMclosed_session1.csv')#, dtype=dtype_dict)

# %%
#Make sure the index provides inforamtion of seconds since start
GRAB_closedopen_1.set_index('Seconds', inplace=True)
GRAB_closedopen_2.set_index('Seconds', inplace=True)

# %%
#Make sure theres a column for session number:
if 'session' not in GRAB_closedopen_1.columns:
    GRAB_closedopen_1['Session'] = 'day1'
if 'session' not in GRAB_closedopen_2.columns:
    GRAB_closedopen_2['Session'] = 'day2'

# %%
#Have a look that the data is as expected
GRAB_closedopen_1
# Out:
#            470_dfF  movementX  movementY  event ExperimentEvents mouseID sex  \
# Seconds
# 0.000    -0.000071   0.007848   0.003241  False              NaN    B3M3   F
# 0.001    -0.000228   0.025288   0.010443  False              NaN    B3M3   F
# 0.002    -0.000385   0.042729   0.017645  False              NaN    B3M3   F
# 0.003    -0.000542   0.060169   0.024846  False              NaN    B3M3   F
# 0.004    -0.000699   0.077609   0.032048  False              NaN    B3M3   F
# ...            ...        ...        ...    ...              ...     ...  ..
# 1916.987 -0.111214   0.008763   0.000103  False              NaN    B3M3   F
# 1916.988 -0.094787   0.006652   0.000078  False              NaN    B3M3   F
# 1916.989 -0.078361   0.004540   0.000054  False              NaN    B3M3   F
# 1916.990 -0.061935   0.002428   0.000029  False              NaN    B3M3   F
# 1916.991 -0.047973   0.000634   0.000007  False              NaN    B3M3   F
#
#          area  No_halt  LinearMismatch_block  LinearPlaybackMismatch_block  \
# Seconds
# 0.000      V1    False                 False                         False
# 0.001      V1    False                 False                         False
# 0.002      V1    False                 False                         False
# 0.003      V1    False                 False                         False
# 0.004      V1    False                 False                         False
# ...       ...      ...                   ...                           ...
# 1916.987   V1    False                 False                         False
# 1916.988   V1    False                 False                         False
# 1916.989   V1    False                 False                         False
# 1916.990   V1    False                 False                         False
# 1916.991   V1    False                 False                         False
#
#          Session
# Seconds
# 0.000       day1
# 0.001       day1
# 0.002       day1
# 0.003       day1
# 0.004       day1
# ...          ...
# 1916.987    day1
# 1916.988    day1
# 1916.989    day1
# 1916.990    day1
# 1916.991    day1
#
# [1916992 rows x 12 columns]

# %%
# Chaning event name to halt and making it so that its True when there is a halt
#GRAB_closedopen_1.loc[:, 'event'] = GRAB_closedopen_1['event'].replace({False: True, True: False})
GRAB_closedopen_1.rename(columns = {'event': 'halt'}, inplace = True)
GRAB_closedopen_2.rename(columns = {'event': 'halt'}, inplace = True)

# %%
#Check that the same mice are in the datsets
print(GRAB_closedopen_1.mouseID.unique())
print(GRAB_closedopen_2.mouseID.unique())
names = GRAB_closedopen_2.mouseID.unique()
# Out:
# ['B3M3']
# ['B3M3']

# %% [markdown]
# # View session data
# - Loop through the mouse names present in one of the dataframes (ideally they should be the same)
# - save a variable where each session is saved for the current mouse
# - use the view_session_mouse() funciton from analysis_functions.py to plot the Delta F/F 470 fluorescence and movement in X direction with halts in grey, and session blocks marked in colors.
# - Can also add other column names to the plotlist, like eye movements and other fluorescent traces
# - This is mostly to get an impression of the overall data trends.
#
# Move the function into this file to test it.

# %%
for mouse in GRAB_closedopen_1.mouseID.unique():
    mousedata = {'session 1':GRAB_closedopen_1.loc[GRAB_closedopen_1.mouseID == mouse], 'session 2':GRAB_closedopen_2.loc[GRAB_closedopen_2.mouseID == mouse]}
    fig, ax = view_session_mouse(mousedata, mouse, plotlist = ['470_dfF', 'movementX'])
    fig.savefig(f'Figures/GRAB{mouse}_view_alignment.png', format = 'png', dpi = 300)
# Out:
# Plotted traces for B3M3

# %% [markdown]
# ## Filter with respect to blocks
# Use the function: filter_data(data, filters = []).
# Ensure that therere is a filter in the filterdict within the function that corresponds to the blocks and other column specified values that you want to filter by.
#
# You can add filters by adding lines to the dict of this format:
#     'filter key name': ['Relevant column name', Relevant row values to filter],
#
# Add the same filters to the dict you define below
#
# * Allways filter by mouse in addition to other filters, if the input data includes multiple animal recordings

# %%
# first make the dict structure
mouse_data = {'session 1':{'closedloop': {}, 'openloop':{}}, 'session 2': {'closedloop': {},'openloop': {}}}

#Then assign mouse by mouse with filtered data to the dict
for mouse in GRAB_closedopen_1.mouseID.unique():
    mouse_data['session 1']['closedloop'][mouse] = filter_data(GRAB_closedopen_1, filters = [mouse, 'closed_block'])
    mouse_data['session 1']['openloop'][mouse] = filter_data(GRAB_closedopen_1, filters = [mouse, 'open_block'])
    
for mouse in GRAB_closedopen_2.mouseID.unique():
    mouse_data['session 2']['closedloop'][mouse] = filter_data(GRAB_closedopen_2, filters = [mouse, 'closed_block'])
    mouse_data['session 2']['openloop'][mouse] = filter_data(GRAB_closedopen_2, filters = [mouse, 'open_block'])

# %% [markdown]
# # Align data and save to dict
# Run process_mouse_data which will call align_to_event_start and align traces and structure tham into a dictionary.
# Specify:
# * The trace columns to align and not baseline
# * The trace columns to align and basline (can be the same as the former)
# * The event column (bool column, halt, No_halt, or other)
# * Saving the event times means that the data can be analysed as a function of what time during the experiment that the halt appeared

# %%
# Example input data (assuming `aligned_data` is structured as needed)
trace_columns_to_baseline = ['470_dfF']  # Columns to baseline
trace_columns_no_baseline = ['movementY', 'movementX']  # Columns to leave unaltered
event_col = 'halt'

# Process the data
aligned_data = process_mouse_data(mouse_data, trace_columns_to_baseline, trace_columns_no_baseline, event_col, [1, 2])

event_col = 'No_halt'
aligned_data_nohalt = process_mouse_data(mouse_data, trace_columns_to_baseline, trace_columns_no_baseline, event_col, [1, 2])

# %%
aligned_data['session 1']['closedloop'][names[0]]
# Out:
# {'470_dfF_bsl':          95.818    118.352   130.985   166.634   181.418   218.467   317.933  \
#  -1.000  0.940702 -1.731282  0.781474  1.690301  0.009972  0.305642  0.233233
#  -0.999  0.931342 -1.721063  0.774932  1.677266 -0.003351  0.286494  0.250710
#  -0.998  0.921983 -1.710845  0.768390  1.679633 -0.016673  0.267346  0.268187
#  -0.997  0.912624 -1.700626  0.761848  1.688250 -0.029996  0.248198  0.285663
#  -0.996  0.903265 -1.690407  0.755306  1.696868 -0.043318  0.229050  0.303140
#  ...          ...       ...       ...       ...       ...       ...       ...
#   1.996  3.320576 -3.531210 -0.797822  1.716482  0.572075  4.096683  0.335255
#   1.997  3.311006 -3.520514 -0.804555  1.702914  0.569838  4.090590  0.353727
#   1.998  3.301437 -3.509818 -0.811287  1.689345  0.567600  4.084496  0.372199
#   1.999  3.291868 -3.499121 -0.818020  1.675777  0.565363  4.078402  0.390671
#   2.000  3.282299 -3.488425 -0.824753  1.662209  0.563125  4.072308  0.409143
#
#           331.949   352.683   369.766   389.816   405.932   614.847   709.529  \
#  -1.000 -0.251512  2.987940  2.258805  0.683377 -1.904610 -0.634118  0.749231
#  -0.999 -0.250878  2.969182  2.299775  0.670856 -1.915210 -0.669873  0.733951
#  -0.998 -0.250066  2.950425  2.340745  0.658336 -1.925811 -0.675260  0.718670
#  -0.997 -0.249254  2.931667  2.381716  0.645815 -1.936412 -0.676597  0.703390
#  -0.996 -0.248442  2.912910  2.422686  0.633294 -1.947012 -0.677934  0.688110
#  ...          ...       ...       ...       ...       ...       ...       ...
#   1.996 -0.169123  1.176965 -1.049179  1.141461 -3.138521  0.008907 -0.422062
#   1.997 -0.165351  1.169980 -1.033230  1.174409 -3.135513 -0.002410 -0.421205
#   1.998 -0.161579  1.163629 -1.017281  1.207358 -3.132504 -0.013727 -0.420348
#   1.999 -0.158105  1.157278 -1.001333  1.240306 -3.129496 -0.025044 -0.419491
#   2.000 -0.173433  1.150927 -0.985384  1.273254 -3.126488 -0.036361 -0.418634
#
#           744.695   772.062   791.645   819.611   841.444
#  -1.000  1.174155 -0.326291  1.302253 -3.402974 -0.513536
#  -0.999  1.166204 -0.332228  1.303590 -3.421113 -0.491446
#  -0.998  1.158254 -0.346796  1.304927 -3.439252 -0.469356
#  -0.997  1.150303 -0.361364  1.306264 -3.457390 -0.447266
#  -0.996  1.143425 -0.375932  1.307601 -3.475529 -0.425176
#  ...          ...       ...       ...       ...       ...
#   1.996 -1.774205 -1.104229 -0.294694 -4.480503 -2.856523
#   1.997 -1.771722 -1.128391 -0.253228 -4.495878 -2.834844
#   1.998 -1.769239 -1.152553 -0.211761 -4.511254 -2.813165
#   1.999 -1.766756 -1.176715 -0.170295 -4.526630 -2.791486
#   2.000 -1.764273 -1.192224 -0.128828 -4.542006 -2.769807
#
#  [3001 rows x 19 columns],
#  'movementY':          95.818    118.352   130.985   166.634   181.418   218.467   317.933  \
#  -1.000  5.619185  4.419108  4.177809  7.018206  1.236015  1.468330  0.755984
#  -0.999  5.773206  4.444778  3.792757  6.915525  1.261685  1.673691  0.832995
#  -0.998  5.878710  4.470448  3.407706  6.812845  1.281965  1.879051  0.910005
#  -0.997  5.815561  4.496118  3.022654  6.710164  1.283505  2.073631  0.987015
#  -0.996  5.738551  4.521788  2.637603  6.607484  1.283505  2.230732  1.064026
#  ...          ...       ...       ...       ...       ...       ...       ...
#   1.996 -0.150170 -1.255268  2.339830  4.899652  0.576294 -3.432092  5.581963
#   1.997 -0.124500 -1.409289  2.365500  5.143005  0.653304 -3.380752  5.675146
#   1.998 -0.098830 -1.471667  2.391170  5.374036  0.730314 -3.329412  5.824546
#   1.999 -0.073160 -1.215479  2.416840  5.605067  0.807325 -3.278072  5.978566
#   2.000 -0.047490 -0.933108  2.442510  5.836097  0.884335 -3.226732  6.132587
#
#           331.949   352.683   369.766   389.816   405.932   614.847   709.529  \
#  -1.000 -1.818727 -0.066742  7.404541  0.297773 -0.165572  0.807325  7.040025
#  -0.999 -1.787666 -0.169423  7.481551 -0.112948 -0.242582  0.884335  6.820032
#  -0.998 -1.737866 -0.272103  7.558561 -0.523670 -0.319593  0.961345  6.281474
#  -0.997 -1.686526 -0.374783  7.635571 -0.934392 -0.396603  1.022183  5.716731
#  -0.996 -1.635185 -0.477464  7.707191 -1.296597 -0.473613  1.026804  5.151989
#  ...          ...       ...       ...       ...       ...       ...       ...
#   1.996  2.582412  1.474747 -0.789356  2.934093  1.911139  1.687809 -0.396603
#   1.997  2.685093  1.535585 -0.917706  2.985433  1.988149  1.816160 -0.473613
#   1.998  2.787773  1.540206 -1.046057  3.036773  2.065160  1.944510 -0.550624
#   1.999  2.890453  1.540206 -1.174407  3.088113  2.142170  2.072861 -0.627634
#   2.000  2.993134  1.540206 -1.302758  3.139453  2.219180  2.201211 -0.704644
#
#           744.695   772.062   791.645   819.611   841.444
#  -1.000  8.051427 -0.496716  2.302608  0.454361  2.780072
#  -0.999  7.820396 -0.727747  2.251268  0.403021  2.831412
#  -0.998  7.589365 -0.958778  2.199928  0.351680  2.882752
#  -0.997  7.358334 -1.189809  2.148587  0.300340  2.934093
#  -0.996  7.127303 -1.420840  2.097247  0.249000  2.985433
#  ...          ...       ...       ...       ...       ...
#   1.996  0.059041  1.436242  0.731598  9.093633  2.027425
#   1.997  0.110381  1.769953  0.474897  8.965283  1.994567
#   1.998  0.161722  2.098274  0.218196  8.836932  1.943227
#   1.999  0.213062  2.407855 -0.038505  8.573814  1.891886
#   2.000  0.264402  2.715897 -0.295206  7.842216  1.840546
#
#  [3001 rows x 19 columns],
#  'movementX':           95.818     118.352    130.985    166.634    181.418    218.467  \
#  -1.000  14.725105  14.314712  16.692395  15.165964  20.615774  22.574328
#  -0.999  14.684782  14.346073  16.714796  15.376537  20.539609  22.592249
#  -0.998  14.641637  14.377435  16.737198  15.587110  20.464386  22.610170
#  -0.997  14.588681  14.408797  16.759599  15.797683  20.392432  22.603629
#  -0.996  14.534917  14.440159  16.782000  16.008257  20.320748  22.512052
#  ...           ...        ...        ...        ...        ...        ...
#   1.996  -0.880823  20.967700  11.610640  18.708072   2.239467  18.997722
#   1.997  -0.898744  20.967700  11.655443  18.639972   2.055775  18.827471
#   1.998  -0.916665  20.944179  11.700245  18.563807   1.872084  18.657221
#   1.999  -0.934586  20.838892  11.745048  18.487642   1.688393  18.486970
#   2.000  -0.952507  20.726885  11.789851  18.411478   1.504701  18.316720
#
#            317.933    331.949    352.683    369.766    389.816    405.932  \
#  -1.000  20.859725  13.851675  23.123162  16.894007  11.586894  24.109719
#  -0.999  20.797001  13.835187  23.096280  16.916409  11.533131  24.029074
#  -0.998  20.734278  13.792535  23.069398  16.938810  11.479368  23.948429
#  -0.997  20.671554  13.747732  23.042517  16.961212  11.425604  23.867784
#  -0.996  20.608830  13.702930  23.015635  16.989258  11.380309  23.787139
#  ...           ...        ...        ...        ...        ...        ...
#   1.996  18.344273   8.049491   0.138217   8.138201   6.003124   5.747972
#   1.997  18.265286   8.098774   0.133736   8.151641   5.940400   5.716610
#   1.998  18.176487   8.148057   0.129256   8.165082   5.877676   5.691834
#   1.999  18.086881   8.197340   0.124776   8.178523   5.814953   5.689953
#   2.000  17.997276   8.246623   0.120295   8.191964   5.752229   5.689953
#
#            614.847    709.529    744.695    772.062    791.645    819.611  \
#  -1.000  19.668419  17.385494  20.853229   7.043221  18.948887   5.415984
#  -0.999  19.668419  17.473487  21.135486   6.984977  18.930966   5.411504
#  -0.998  19.668419  17.509150  21.417744   6.926733  18.913045   5.407023
#  -0.997  19.662774  17.540512  21.700001   6.868490  18.895124   5.402543
#  -0.996  19.637506  17.571873  21.982259   6.810246  18.877202   5.398063
#  ...           ...        ...        ...        ...        ...        ...
#   1.996  15.794547   1.584450  24.414378  21.407215  15.314261  13.665743
#   1.997  15.745264   1.544128  24.333733  21.290728  15.229136  13.791191
#   1.998  15.695981   1.503805  24.253088  21.180827  15.144011  13.916639
#   1.999  15.646698   1.463483  24.172443  21.093820  15.058886  14.030796
#   2.000  15.597415   1.423160  24.091798  21.008695  14.973760  14.105707
#
#            841.444
#  -1.000   8.424490
#  -0.999   8.554418
#  -0.998   8.684346
#  -0.997   8.814274
#  -0.996   8.944203
#  ...           ...
#   1.996  10.163779
#   1.997  10.118707
#   1.998  10.073905
#   1.999  10.029102
#   2.000   9.984299
#
#  [3001 rows x 19 columns]}

# %%
plot_compare_blocks(aligned_data['session 1'], '470_dfF_bsl')
plot_compare_blocks(aligned_data['session 2'], '470_dfF_bsl')

# %%
plot_compare_blocks(aligned_data['session 1'], 'movementX')
plot_compare_blocks(aligned_data['session 2'], 'movementX')

# %% [markdown]
# # Plot across mouse means
# Make dicts with mouse mean data depending on session and blocks, and make also a dict with the controls.
#
# Use these to plot the across mouse means using the plot_mean_across_blocks function.

# %%
mouse_mean_session_data = mouse_mean_bsl_data(aligned_data, '470_dfF_bsl')
mouse_mean_control_data = mouse_mean_bsl_data(aligned_data_nohalt, '470_dfF_bsl')

# %%
# plotting dicts
session1_blocks = {'closedloop': mouse_mean_session_data['session 1']['closedloop'],
                  'openloop': mouse_mean_session_data['session 1']['openloop']}
control1_blocks = {'closedloop': mouse_mean_control_data['session 1']['closedloop']}

session2_blocks = {'closedloop': mouse_mean_session_data['session 2']['closedloop'],
                  'openloop': mouse_mean_session_data['session 2']['openloop']}
control2_blocks = {'closedloop': mouse_mean_control_data['session 2']['closedloop']}

# %%
# Plot the data
plot_mean_across_blocks(session1_blocks, control1_blocks, title="Session 1 blocks")
plot_mean_across_blocks(session2_blocks, control1_blocks, title="Session 2 blocks")

# %% [markdown]
# # Compute statistics
# Use the compute_trace_statistics to get some paramters from the data.
# It will return the peak, mean, median and standard deviation for each aligned trace chunk during the time windows 0-1s, 1-2s, and -1-0s.
# * Specify the aligned trace that you want statistics for
# * In addition you can specify some other traces for which you will get the mean during, after, and before (same time intervals)
#
# * Consider doing this for multiple main traces. Then add a column named for example 'trace' where the main trace name is the value of each row. Combe them all in one df.

# %%
# Specify the main trace and co-traces
main_trace = "470_dfF_bsl"
co_traces = ["movementX", "movementY"]
ranges = [(-1, 0), (0, 1), (1, 2)]

# Compute statistics
stats_470_main_df = compute_trace_statistics(aligned_data,trace=main_trace,co_traces=co_traces,ranges=ranges,)


stats_470_nohalt_df = compute_trace_statistics(aligned_data_nohalt,trace=main_trace,co_traces=co_traces,ranges=ranges,)
# Before combinind datasets, introduce a column to seperate the types of data. 
# Can also be control True and False or other specific event that makes the datsets different
stats_470_main_df['halt'] = True
stats_470_nohalt_df['halt'] = False

# Combine both datasets 
all_470_stats_df = pd.concat([stats_470_main_df, stats_470_nohalt_df], ignore_index=True)
all_470_stats_df
# Out:
#        session  block_type mouse_id  event_time  movementX_prior  \
# 0    session 1  closedloop     B3M3      95.818        14.744543
# 1    session 1  closedloop     B3M3      95.818        14.744543
# 2    session 1  closedloop     B3M3      95.818        14.744543
# 3    session 1  closedloop     B3M3     118.352        15.799878
# 4    session 1  closedloop     B3M3     118.352        15.799878
# ..         ...         ...      ...         ...              ...
# 505  session 2    openloop     B3M3    1812.040        -0.093984
# 506  session 2    openloop     B3M3    1812.040        -0.093984
# 507  session 2    openloop     B3M3    1857.821        21.159917
# 508  session 2    openloop     B3M3    1857.821        21.159917
# 509  session 2    openloop     B3M3    1857.821        21.159917
#
#      movementY_prior time_range  valid_data       peak      mean    median  \
# 0           2.121528      -1-0s        True   1.475076 -0.001464  0.158885
# 1           2.121528       0-1s        True   5.315242  1.509365  1.309904
# 2           2.121528       1-2s        True   5.275810  3.832685  3.898209
# 3           2.204030      -1-0s        True   3.709250 -0.000857  0.109697
# 4           2.204030       0-1s        True   1.542921  0.064895  0.139069
# ..               ...        ...         ...        ...       ...       ...
# 505         0.317783       0-1s        True   1.251757 -0.166572 -0.354865
# 506         0.317783       1-2s        True  10.747248  2.588257 -0.264668
# 507         2.824267      -1-0s        True   2.292401 -0.001689  0.137534
# 508         2.824267       0-1s        True  -0.100854 -1.517470 -1.656679
# 509         2.824267       1-2s        True   0.020601 -1.603167 -1.744439
#
#        stderr   halt
# 0    0.023800   True
# 1    0.086313   True
# 2    0.021136   True
# 3    0.062860   True
# 4    0.021871   True
# ..        ...    ...
# 505  0.022298  False
# 506  0.137419  False
# 507  0.048282  False
# 508  0.020027  False
# 509  0.022086  False
#
# [510 rows x 13 columns]

# %%
all_470_stats_df.to_csv('saved_data/GRAB_closedopenMM_all_470_stats_df.csv')

# %%
##Consider adding to the fitted model a continous variable which is the time column
#EventTime should currently be seconds from session start

# %% [markdown]
# ##  Possible: Look for correlation between running and fluorescence changes

# %%
subset = filter_data(GRAB_closedopen_1, [names[0], 'day1'])

# %%
GRAB_closedopen_1
# Out:
#            470_dfF  movementX  movementY   halt ExperimentEvents mouseID sex  \
# Seconds
# 0.000    -0.000071   0.007848   0.003241  False              NaN    B3M3   F
# 0.001    -0.000228   0.025288   0.010443  False              NaN    B3M3   F
# 0.002    -0.000385   0.042729   0.017645  False              NaN    B3M3   F
# 0.003    -0.000542   0.060169   0.024846  False              NaN    B3M3   F
# 0.004    -0.000699   0.077609   0.032048  False              NaN    B3M3   F
# ...            ...        ...        ...    ...              ...     ...  ..
# 1916.987 -0.111214   0.008763   0.000103  False              NaN    B3M3   F
# 1916.988 -0.094787   0.006652   0.000078  False              NaN    B3M3   F
# 1916.989 -0.078361   0.004540   0.000054  False              NaN    B3M3   F
# 1916.990 -0.061935   0.002428   0.000029  False              NaN    B3M3   F
# 1916.991 -0.047973   0.000634   0.000007  False              NaN    B3M3   F
#
#          area  No_halt  LinearMismatch_block  LinearPlaybackMismatch_block  \
# Seconds
# 0.000      V1    False                 False                         False
# 0.001      V1    False                 False                         False
# 0.002      V1    False                 False                         False
# 0.003      V1    False                 False                         False
# 0.004      V1    False                 False                         False
# ...       ...      ...                   ...                           ...
# 1916.987   V1    False                 False                         False
# 1916.988   V1    False                 False                         False
# 1916.989   V1    False                 False                         False
# 1916.990   V1    False                 False                         False
# 1916.991   V1    False                 False                         False
#
#          Session
# Seconds
# 0.000       day1
# 0.001       day1
# 0.002       day1
# 0.003       day1
# 0.004       day1
# ...          ...
# 1916.987    day1
# 1916.988    day1
# 1916.989    day1
# 1916.990    day1
# 1916.991    day1
#
# [1916992 rows x 12 columns]

# %%
# Compute Pearson correlation
pearson_corr, pearson_pval = pearsonr(subset['movementX'], subset['470_dfF'])

# Compute Spearman correlation (handles nonlinear relationships better)
spearman_corr, spearman_pval = spearmanr(subset['movementX'], subset['470_dfF'])

print(f"Pearson correlation: {pearson_corr}, p-value: {pearson_pval}")
print(f"Spearman correlation: {spearman_corr}, p-value: {spearman_pval}")
# Out:
# Pearson correlation: 0.019730870693163396, p-value: 2.381074833391069e-164
# Spearman correlation: 0.07861897969547967, p-value: 0.0

# %%
resampled = subset.sample(10000, random_state=9)  # Sample 10,000 rows
pearson_corr, pearson_pval = pearsonr(resampled['movementX'], resampled['470_dfF'])
spearman_corr, spearman_pval = spearmanr(resampled['movementX'], resampled['470_dfF'])
print(f"Subset Pearson correlation: {pearson_corr}, p-value: {pearson_pval}")
print(f"Subset Spearman correlation: {spearman_corr}, p-value: {spearman_pval}")
# Out:
# Subset Pearson correlation: 0.023310403014089875, p-value: 0.019749899908894523
# Subset Spearman correlation: 0.08003878950072392, p-value: 1.0947568475051606e-15
