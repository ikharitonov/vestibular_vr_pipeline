# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ellipse import LsqEllipse
from vestibular_vr_pipeline.sleap import load_and_process as lp
from scipy.ndimage import median_filter

# %%
path = '/home/ikharitonov/RANCZLAB-NAS/data/ONIX/20240730_Mismatch_Experiment/training_day4/2024-08-02T12-25-55_B3M3/VideoData2/'
file = 'VideoData2_1904-01-03T23-00-00.sleap.csv'
df = lp.load_df(path+file)
df = df.drop(columns=['track'])
df
# Out:
#        frame_idx  instance.score      left.x      left.y  left.score  \
# 0              0             NaN  163.904974  295.557557         NaN
# 1              1       10.212954  163.736450  295.647064    0.982247
# 2              2       10.359891  163.699326  292.336151    1.016272
# 3              3       10.421487  163.845123  292.215546    1.002152
# 4              4       10.338270  163.904037  292.269867    0.990069
# ...          ...             ...         ...         ...         ...
# 13156      13169       10.943019  163.889038  296.045685    1.053002
# 13157      13170       10.798992  163.908539  296.210327    1.022105
# 13158      13171       10.748046  163.904465  296.522003    1.027911
# 13159      13172       10.855190  163.945602  296.301392    1.041812
# 13160      13173       10.855741  163.908859  296.111450    1.060403
#
#          center.x    center.y  center.score     right.x     right.y  ...  \
# 0      239.196627  271.760077           NaN  366.443379  260.912401  ...
# 1      239.632309  272.209320      0.934060  364.320496  260.253998  ...
# 2      239.667587  272.167084      0.952217  364.176971  260.225494  ...
# 3      239.793808  272.148193      0.966211  364.096405  260.082977  ...
# 4      239.660767  272.159058      0.958359  364.033478  260.118927  ...
# ...           ...         ...           ...         ...         ...  ...
# 13156  255.849091  271.744476      1.020667  368.048462  263.937317  ...
# 13157  255.856354  271.819305      0.978433  371.671021  264.292725  ...
# 13158  256.044312  271.895325      0.997026  371.834106  264.349152  ...
# 13159  255.863022  271.897919      0.998376  371.595123  263.977753  ...
# 13160  255.855896  271.790619      0.997417  368.015686  263.818237  ...
#
#        p2.score        p8.x        p8.y  p8.score        p4.x        p4.y  \
# 0           NaN  225.328382  289.897119       NaN  253.816808  257.256062
# 1      0.956285  227.285034  288.264862  0.863690  252.411591  256.382965
# 2      0.968861  227.406708  288.120575  0.896477  252.438568  259.415466
# 3      0.975506  227.593399  288.053528  0.912141  252.433060  259.600403
# 4      0.957251  227.465668  287.979095  0.891923  252.383286  259.577850
# ...         ...         ...         ...       ...         ...         ...
# 13156  1.031755  247.637985  280.235352  1.051277  263.979797  263.441223
# 13157  0.992947  247.759415  280.189575  1.028840  263.907928  263.627411
# 13158  1.013916  247.730804  280.390411  1.011382  264.297302  263.560760
# 13159  0.994463  247.702896  280.303802  1.044879  263.905426  263.699432
# 13160  0.997016  247.796127  280.131409  1.066634  263.796173  263.653931
#
#        p4.score        p6.x        p6.y  p6.score
# 0           NaN  252.579801  289.149341       NaN
# 1      0.952811  251.869720  288.116882  0.880531
# 2      0.947811  251.878326  288.028381  0.902798
# 3      0.957559  251.877472  287.928223  0.921246
# 4      0.953956  251.919052  287.900940  0.915891
# ...         ...         ...         ...       ...
# 13156  1.006624  264.277039  280.243317  0.982499
# 13157  1.004144  264.159576  280.231110  0.962978
# 13158  0.994487  264.514343  283.429077  0.947689
# 13159  1.007771  264.195557  280.328369  0.958097
# 13160  0.988427  264.197998  280.106781  0.970594
#
# [13161 rows x 35 columns]

# %%
columns_of_interest = ['left.x','left.y','center.x','center.y','right.x','right.y','p1.x','p1.y','p2.x','p2.y','p3.x','p3.y','p4.x','p4.y','p5.x','p5.y','p6.x','p6.y','p7.x','p7.y','p8.x','p8.y']
coordinates_dict = lp.get_coordinates_dict(df, columns_of_interest)

# %%
plt.scatter(coordinates_dict['left.x'], coordinates_dict['left.y'])
plt.scatter(coordinates_dict['right.x'], coordinates_dict['right.y'])
plt.show()

# %%
theta = lp.find_horizontal_axis_angle(df, 'left', 'center')
theta
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 theta = lp.find_horizontal_axis_angle(df, 'left', 'center')
#       2 theta
#
# File ~/code/aeon_mecha/summer_2024_harp_sleap_pnn_analysis/sleap/load_and_process.py:158, in find_horizontal_axis_angle(df, point1, point2)
#     156 def find_horizontal_axis_angle(df, point1='left', point2='center'):
#     157     # Fits a line between original (unreferenced) left reference point and center of the pupil point, return the angle of the line
# --> 158     line_fn = np.polyfit(np.hstack([df[f'{point1}.x'].to_numpy(), df[f'{point2}.x'].to_numpy()]), np.hstack([df[f'{point1}.y'].to_numpy(), df[f'{point2}.y'].to_numpy()]), 1)
#     159     line_fn = np.poly1d(line_fn)
#     160     theta = np.arctan(line_fn[1])
#
# File ~/anaconda3/envs/aeon/lib/python3.12/site-packages/numpy/lib/polynomial.py:669, in polyfit(x, y, deg, rcond, full, w, cov)
#     667 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     668 lhs /= scale
# --> 669 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     670 c = (c.T/scale).T  # broadcast scale coefficients
#     672 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File ~/anaconda3/envs/aeon/lib/python3.12/site-packages/numpy/linalg/linalg.py:2326, in lstsq(a, b, rcond)
#    2323 if n_rhs == 0:
#    2324     # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2325     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2326 x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2327 if m == 0:
#    2328     x[...] = 0
#
# File ~/anaconda3/envs/aeon/lib/python3.12/site-packages/numpy/linalg/linalg.py:124, in _raise_linalgerror_lstsq(err, flag)
#     123 def _raise_linalgerror_lstsq(err, flag):
# --> 124     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %%
center_point = lp.get_left_right_center_point(coordinates_dict)
center_point
# Out:
# (nan, nan)

# %%
columns_of_interest = ['left', 'right', 'center', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8']
remformatted_coordinates_dict = lp.get_reformatted_coordinates_dict(coordinates_dict, columns_of_interest)
centered_coordinates_dict = lp.get_centered_coordinates_dict(remformatted_coordinates_dict, center_point)
rotated_coordinates_dict = lp.get_rotated_coordinates_dict(centered_coordinates_dict, theta)

# %%
plt.title('Centering and alignment')

plt.scatter(remformatted_coordinates_dict['left'][:,0], remformatted_coordinates_dict['left'][:,1], s=2, alpha=0.5)
plt.scatter(remformatted_coordinates_dict['right'][:,0], remformatted_coordinates_dict['right'][:,1], s=2, alpha=0.5)

plt.scatter(centered_coordinates_dict['left'][:,0], centered_coordinates_dict['left'][:,1], s=2, alpha=0.5)
plt.scatter(centered_coordinates_dict['right'][:,0], centered_coordinates_dict['right'][:,1], s=2, alpha=0.5)


plt.scatter(rotated_coordinates_dict['left'][:,0], rotated_coordinates_dict['left'][:,1], s=2, alpha=0.5)
plt.scatter(rotated_coordinates_dict['right'][:,0], rotated_coordinates_dict['right'][:,1], s=2, alpha=0.5)

plt.scatter(center_point[0], center_point[1], s=50, c='black')
plt.scatter(0, 0, s=50, c='black')
plt.arrow(center_point[0], center_point[1], -center_point[0], -center_point[1], length_includes_head=True, head_width=10, color='black')

plt.legend(['left original', 'right original', 'left centered', 'right centered', 'left rotated', 'right rotated'])
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.show()

# %%
for point, arr in centered_coordinates_dict.items():
    plt.scatter(arr[:,0], arr[:,1], c='blue', alpha=0.5)

for point, arr in rotated_coordinates_dict.items():
    plt.scatter(arr[:,0], arr[:,1], c='orange', alpha=0.5)

plt.grid()
plt.show()

# %%
ellipse_parameters_data, ellipse_center_points_data = lp.get_fitted_ellipse_parameters(rotated_coordinates_dict, ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8'])
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ellipse_parameters_data, ellipse_center_points_data = lp.get_fitted_ellipse_parameters(rotated_coordinates_dict, ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8'])
#
# File ~/code/aeon_mecha/summer_2024_harp_sleap_pnn_analysis/sleap/load_and_process.py:241, in get_fitted_ellipse_parameters(coordinates_dict, columns_of_interest)
#     239 ellipse_center_points_data = []
#     240 for t in range(coordinates_dict[list(coordinates_dict.keys())[0]].shape[0]):
# --> 241     reg = LsqEllipse().fit(get_eight_points_at_time(coordinates_dict, columns_of_interest, t))
#     242     center, width, height, phi = reg.as_parameters()
#     243     ellipse_parameters_data.append([width, height, phi])
#
# File ~/anaconda3/envs/aeon/lib/python3.12/site-packages/ellipse.py:104, in LsqEllipse.fit(self, X)
#     100 M = la.inv(C1) @ (S1 - S2 @ la.inv(S3) @ S2.T)
#     102 # M*|a b c >=l|a b c >. Find eigenvalues and eigenvectors from this
#     103 # equation [eqn. 28]
# --> 104 eigval, eigvec = np.linalg.eig(M)
#     106 # Eigenvector must meet constraint 4ac - b^2 to be valid.
#     107 cond = 4*np.multiply(eigvec[0, :], eigvec[2, :]) - np.power(eigvec[1, :], 2)
#
# File ~/anaconda3/envs/aeon/lib/python3.12/site-packages/numpy/linalg/linalg.py:1329, in eig(a)
#    1327 _assert_stacked_2d(a)
#    1328 _assert_stacked_square(a)
# -> 1329 _assert_finite(a)
#    1330 t, result_t = _commonType(a)
#    1332 extobj = get_linalg_error_extobj(
#    1333     _raise_linalgerror_eigenvalues_nonconvergence)
#
# File ~/anaconda3/envs/aeon/lib/python3.12/site-packages/numpy/linalg/linalg.py:218, in _assert_finite(*arrays)
#     216 for a in arrays:
#     217     if not isfinite(a).all():
# --> 218         raise LinAlgError("Array must not contain infs or NaNs")
#
# LinAlgError: Array must not contain infs or NaNs

# %%
a = 0
b = 600
plt.figure(figsize=(10,5))
plt.title('SLEAP vs fitted ellipse comparison')
plt.plot(rotated_coordinates_dict['center'][a:b,0])
plt.plot(ellipse_center_points_data[a:b,0])
# plt.plot(moving_average_smoothing(ellipse_center_points_data[a:b,0], 10))
# plt.plot(median_filter(ellipse_center_points_data[a:b,0], size=10))
# plt.legend(['SLEAP center', 'Fitted ellipse center', '5 point moving average fitted ellipse', 'Size 5 median filter fitted ellipse'])
plt.legend(['SLEAP center', 'Fitted ellipse center'])
plt.xlabel('frame')
plt.ylabel('x')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       4 plt.title('SLEAP vs fitted ellipse comparison')
#       5 plt.plot(rotated_coordinates_dict['center'][a:b,0])
# ----> 6 plt.plot(ellipse_center_points_data[a:b,0])
#       7 # plt.plot(moving_average_smoothing(ellipse_center_points_data[a:b,0], 10))
#       8 # plt.plot(median_filter(ellipse_center_points_data[a:b,0], size=10))
#       9 # plt.legend(['SLEAP center', 'Fitted ellipse center', '5 point moving average fitted ellipse', 'Size 5 median filter fitted ellipse'])
#      10 plt.legend(['SLEAP center', 'Fitted ellipse center'])
#
# NameError: name 'ellipse_center_points_data' is not defined

# %%
a = 3200
b = 3400
plt.figure(figsize=(10,5))
plt.title('SLEAP vs fitted ellipse comparison')
plt.plot(rotated_coordinates_dict['center'][a:b,0])
plt.plot(ellipse_center_points_data[a:b,0])
# plt.plot(moving_average_smoothing(ellipse_center_points_data[a:b,0], 10))
# plt.plot(median_filter(ellipse_center_points_data[a:b,0], size=10))
# plt.legend(['SLEAP center', 'Fitted ellipse center', '5 point moving average fitted ellipse', 'Size 5 median filter fitted ellipse'])
plt.legend(['SLEAP center', 'Fitted ellipse center'])
plt.xlabel('frame')
plt.ylabel('x')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       4 plt.title('SLEAP vs fitted ellipse comparison')
#       5 plt.plot(rotated_coordinates_dict['center'][a:b,0])
# ----> 6 plt.plot(ellipse_center_points_data[a:b,0])
#       7 # plt.plot(moving_average_smoothing(ellipse_center_points_data[a:b,0], 10))
#       8 # plt.plot(median_filter(ellipse_center_points_data[a:b,0], size=10))
#       9 # plt.legend(['SLEAP center', 'Fitted ellipse center', '5 point moving average fitted ellipse', 'Size 5 median filter fitted ellipse'])
#      10 plt.legend(['SLEAP center', 'Fitted ellipse center'])
#
# NameError: name 'ellipse_center_points_data' is not defined
