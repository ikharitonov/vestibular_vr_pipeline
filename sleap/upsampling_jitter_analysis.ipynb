# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/ikharitonov/Desktop/'
files = ['20204321_343_6_ORIGINAL.csv',
        '20204321_343_6_LANCZOS_4x.csv',
        '20204321_343_6_LANCZOS_8x.csv',
        '20204321_343_6_LANCZOS_8x_RETRAINED.csv']

# %%
dfs = {f:pd.read_csv(path+f) for f in files}

# %%
list(dfs.values())[0]
# Out:
#       track  frame_idx  instance.score  left.x  left.y  left.score  \
# 0       NaN          0        8.856275     NaN     NaN         0.0
# 1       NaN          1        8.813431     NaN     NaN         0.0
# 2       NaN          2        8.889629     NaN     NaN         0.0
# 3       NaN          3        8.885150     NaN     NaN         0.0
# 4       NaN          4        8.927650     NaN     NaN         0.0
# ...     ...        ...             ...     ...     ...         ...
# 6439    NaN       6439        8.745234     NaN     NaN         0.0
# 6440    NaN       6440        8.751877     NaN     NaN         0.0
# 6441    NaN       6441        8.700216     NaN     NaN         0.0
# 6442    NaN       6442        8.725132     NaN     NaN         0.0
# 6443    NaN       6443        8.872622     NaN     NaN         0.0
#
#         center.x    center.y  center.score     right.x  ...  p2.score  \
# 0     111.745209  165.732407      0.902241  249.897980  ...  0.933758
# 1     110.164803  165.772614      0.905799  249.940155  ...  0.940834
# 2     110.186035  164.211899      0.919074  250.095062  ...  0.954729
# 3     111.813919  165.761536      0.919616  250.220718  ...  0.942041
# 4     111.806473  165.759247      0.923594  250.131226  ...  0.955877
# ...          ...         ...           ...         ...  ...       ...
# 6439  115.996071  168.217178      0.882125  251.808731  ...  0.940370
# 6440  115.917725  168.114319      0.886868  250.251816  ...  0.961784
# 6441  115.891174  168.127716      0.871390  251.815750  ...  0.952711
# 6442  115.908684  168.067215      0.863217  251.756180  ...  0.952808
# 6443  115.886574  168.092224      0.877849  251.882996  ...  0.958876
#
#            p8.x        p8.y  p8.score        p4.x        p4.y  p4.score  \
# 0     90.271133  182.008240  0.883072  126.106819  147.865372  0.863144
# 1     90.114006  181.987747  0.912145  126.098755  147.921951  0.851953
# 2     90.152534  181.828445  0.917200  126.138435  147.905792  0.861193
# 3     91.866661  182.092163  0.917778  127.737564  147.921494  0.856919
# 4     91.859886  182.063370  0.926126  127.740341  147.912811  0.860749
# ...         ...         ...       ...         ...         ...       ...
# 6439  96.156471  186.081726  0.894601  130.229752  150.137894  0.836130
# 6440  95.966881  185.937042  0.898840  130.200287  150.043442  0.834979
# 6441  96.038139  185.946075  0.893707  130.121597  150.073227  0.813941
# 6442  96.156723  186.006760  0.876679  130.150345  149.984741  0.814940
# 6443  96.079872  185.880478  0.883807  130.089264  150.087357  0.851155
#
#             p6.x        p6.y  p6.score
# 0     131.788986  184.211853  0.816904
# 1     131.800064  184.215683  0.804510
# 2     130.257263  184.119095  0.822138
# 3     131.971268  184.119385  0.813176
# 4     131.974533  184.165863  0.802920
# ...          ...         ...       ...
# 6439  136.220688  186.311310  0.826373
# 6440  136.080627  186.217834  0.820773
# 6441  136.128769  186.332077  0.791839
# 6442  136.189438  186.158859  0.833386
# 6443  136.134232  186.200104  0.850245
#
# [6444 rows x 36 columns]

# %%
for name, df in dfs.items():
    plt.figure(figsize=(10,5))
    plt.title(name)
    plt.plot(df['center.x'][100:125])
#     plt.xlim([0,500])
    plt.show()
