# %% [markdown]
# ## Setup

# %%
import numpy as np
from pathlib import Path
import os
import matplotlib.pyplot as plt
import pandas as pd

from harp_resources import process, utils
from sleap import load_and_process as lp

# %%
data_path = Path('/home/ikharitonov/RANCZLAB-NAS/data/ONIX/20240730_Mismatch_Experiment/GRAB_MMclosed&Regular_230824/2024-08-23T14-14-16_B3M4')
photometry_path = Path('/home/ikharitonov/RANCZLAB-NAS/data/ONIX/20240730_Mismatch_Experiment/GRAB_MMclosed&Regular_230824/photometry/B3M4_MMclosed&Regular_day2/2024_08_23-16_17_49')

# %% [markdown]
# ## Videography and SLEAP

# %%
lp.create_flipped_videos(data_path, what_to_flip='VideoData1')
# Out:
# Flipped video saved as: /home/ikharitonov/RANCZLAB-NAS/data/ONIX/20240730_Mismatch_Experiment/GRAB_MMclosed&Regular_230824/2024-08-23T14-14-16_B3M4/VideoData1/VideoData1_1904-01-06T03-00-00.flipped.avi

# %% [markdown]
# ## RUN Sleap inference now

# %%
VideoData1, VideoData2 = lp.load_videography_data(data_path)
# Out:
# INFO:
# load_and_process.load_videography_data() function expects the following format of SLEAP outputs:
# "VideoData1_1904-01-01T00-00-00.sleap.csv"
# "VideoData1_1904-01-01T23-59-59.sleap.csv"
# "..."
# Please make sure to rename SLEAP files if they are not already following this convention.
#
#
# RESULTS:
# Outputs of SLEAP found in VideoData1: False
# Outputs of SLEAP found in VideoData2: True
# Found .csv VideoData logs timestamped at:
# - 1904-01-06T03:00:00.000000000
# Reading dataframes finished.
# VideoData2 SLEAP output: 114983 frames registered, but 114584 rows found inside file. Filling with empty rows.

# %%
# SLEAP processing

VideoData2 = VideoData2.interpolate()

columns_of_interest = ['left.x','left.y','center.x','center.y','right.x','right.y','p1.x','p1.y','p2.x','p2.y','p3.x','p3.y','p4.x','p4.y','p5.x','p5.y','p6.x','p6.y','p7.x','p7.y','p8.x','p8.y']
coordinates_dict =lp.get_coordinates_dict(VideoData2, columns_of_interest)

theta = lp.find_horizontal_axis_angle(VideoData2, 'left', 'center')
center_point = lp.get_left_right_center_point(coordinates_dict)

columns_of_interest = ['left', 'right', 'center', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8']
remformatted_coordinates_dict = lp.get_reformatted_coordinates_dict(coordinates_dict, columns_of_interest)
centered_coordinates_dict = lp.get_centered_coordinates_dict(remformatted_coordinates_dict, center_point)
rotated_coordinates_dict = lp.get_rotated_coordinates_dict(centered_coordinates_dict, theta)

columns_of_interest = ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8']
ellipse_parameters_data, ellipse_center_points_data = lp.get_fitted_ellipse_parameters(rotated_coordinates_dict, columns_of_interest)

SleapData = process.convert_arrays_to_dataframe(['Seconds', 'Ellipse.Width', 'Ellipse.Height', 'Ellipse.Angle', 'Ellipse.Center.X', 'Ellipse.Center.Y'], [VideoData2['Seconds'].values, ellipse_parameters_data[:,0], ellipse_parameters_data[:,1], ellipse_parameters_data[:,2], ellipse_center_points_data[:,0], ellipse_center_points_data[:,1]])

# %% [markdown]
# ## Loading and Synchronisation

# %%
conversions = process.calculate_conversions_second_approach(data_path, photometry_path, verbose=True)
# Out:
# OnixAnalogClock loaded in 0.88 seconds.
# Following conversion functions calculated:
# 	onix_to_harp_timestamp
# 	harp_to_onix_clock
# 	photometry_to_harp_time
# 	onix_time_to_photometry
#
# Usage example 1: plotting photodiode signal for three halts
#
# 	# Loading data
# 	OnixAnalogClock = utils.read_OnixAnalogClock(data_path)
# 	OnixAnalogData = utils.read_OnixAnalogData(data_path)
# 	ExperimentEvents = utils.read_ExperimentEvents(data_path)
#
# 	# Selecting desired HARP times, applying conversion to ONIX time
# 	start_harp_time_of_halt_one = ExperimentEvents[ExperimentEvents.Value=='Apply halt: 1s'].iloc[0].Seconds
# 	start_harp_time_of_halt_four = ExperimentEvents[ExperimentEvents.Value=='Apply halt: 1s'].iloc[3].Seconds
# 	start_onix_time = conversions['harp_to_onix_clock'](start_harp_time_of_halt_one - 1)
# 	end_onix_time = conversions['harp_to_onix_clock'](start_harp_time_of_halt_four)
#
# 	# Selecting photodiode times and data within the range, converting back to HARP and plotting
# 	indices = np.where(np.logical_and(OnixAnalogClock >= start_onix_time, OnixAnalogClock <= end_onix_time))
# 	selected_harp_times = conversions['onix_to_harp_timestamp'](OnixAnalogClock[indices])
# 	selected_photodiode_data = OnixAnalogData[indices]
# 	plt.plot(selected_harp_times, selected_photodiode_data[:, 0])
#
# Usage example 2: plot photometry in the same time range
#
# 	Photometry = utils.read_fluorescence(photometry_path)
#
# 	start_photometry_time = conversions['onix_time_to_photometry'](start_onix_time)
# 	end_photometry_time = conversions['onix_time_to_photometry'](end_onix_time)
#
# 	selected_photometry_data = Photometry[Photometry['TimeStamp'].between(start_photometry_time, end_photometry_time)]['CH1-470'].values
# 	selected_harp_times = conversions['photometry_to_harp_time'](Photometry[Photometry['TimeStamp'].between(start_photometry_time, end_photometry_time)]['TimeStamp'])
# 	plt.plot(selected_harp_times, selected_photometry_data)
#
# It is best not to convert the whole OnixAnalogClock array to HARP timestamps at once (e.g. conversions['onix_to_harp_timestamp'](OnixAnalogClock)). It's faster to first find the necessary timestamps and indices in ONIX format as shown above.
# Calculation of conversions finished in 12.07 seconds.

# %%
streams = utils.load_registers(data_path)

Photometry = utils.read_fluorescence(photometry_path)
Photometry['HARP Timestamps'] = conversions['photometry_to_harp_time'](Photometry['TimeStamp'])

streams = process.reformat_and_add_many_streams(streams, Photometry, 'Photometry', ['CH1-410', 'CH1-470', 'CH1-560'], index_column_name='HARP Timestamps')
streams = process.reformat_and_add_many_streams(streams, SleapData, 'Eye Movements', ['Ellipse.Width', 'Ellipse.Height', 'Ellipse.Angle', 'Ellipse.Center.X', 'Ellipse.Center.Y'])

_ = process.get_timepoint_info(streams, print_all=True)
resampled_streams = process.pad_and_resample(streams, resampling_period='0.1ms', method='linear')
_ = process.get_timepoint_info(resampled_streams, print_all=True)
# Out:
# Dataset 2024-08-23T14-14-16_B3M4 contains following registers:
# H1: [46, 32, 33]
# H2: [42, 39]
# Registers loaded in 2.14 seconds.
# Global first timestamp: 1904-01-06 03:09:48.814600128
# Global last timestamp: 1904-01-06 03:42:07.582796833
# Global length: 0 days 00:32:18.768196705
#
# H1
# OpticalTrackingRead0X(46):
# 	first  1904-01-06 03:10:01.540256
# 	last   1904-01-06 03:41:57.710240
# 	length 0 days 00:31:56.169984
# 	mean difference between timestamps 0 days 00:00:00.009999999
# OpticalTrackingRead0Y(46):
# 	first  1904-01-06 03:10:01.540256
# 	last   1904-01-06 03:41:57.710240
# 	length 0 days 00:31:56.169984
# 	mean difference between timestamps 0 days 00:00:00.009999999
# OpticalTrackingRead0Brightness(46):
# 	first  1904-01-06 03:10:01.540256
# 	last   1904-01-06 03:41:57.710240
# 	length 0 days 00:31:56.169984
# 	mean difference between timestamps 0 days 00:00:00.009999999
# OpticalTrackingRead1X(46):
# 	first  1904-01-06 03:10:01.540256
# 	last   1904-01-06 03:41:57.710240
# 	length 0 days 00:31:56.169984
# 	mean difference between timestamps 0 days 00:00:00.009999999
# OpticalTrackingRead1Y(46):
# 	first  1904-01-06 03:10:01.540256
# 	last   1904-01-06 03:41:57.710240
# 	length 0 days 00:31:56.169984
# 	mean difference between timestamps 0 days 00:00:00.009999999
# OpticalTrackingRead1Brightness(46):
# 	first  1904-01-06 03:10:01.540256
# 	last   1904-01-06 03:41:57.710240
# 	length 0 days 00:31:56.169984
# 	mean difference between timestamps 0 days 00:00:00.009999999
# Cam0Event(32):
# 	first  1904-01-06 03:10:01.532031999
# 	last   1904-01-06 03:41:57.696672
# 	length 0 days 00:31:56.164640001
# 	mean difference between timestamps 0 days 00:00:00.016666069
# Cam1Event(33):
# 	first  1904-01-06 03:10:01.532031999
# 	last   1904-01-06 03:41:57.696672
# 	length 0 days 00:31:56.164640001
# 	mean difference between timestamps 0 days 00:00:00.016666069
#
# H2
# ImmediatePulses(42):
# 	first  1904-01-06 03:10:11.256480
# 	last   1904-01-06 03:31:06.410496
# 	length 0 days 00:20:55.154016
# 	mean difference between timestamps 0 days 00:04:11.030803200
# AnalogInput(39):
# 	first  1904-01-06 03:10:01.537504
# 	last   1904-01-06 03:41:57.864992
# 	length 0 days 00:31:56.327488
# 	mean difference between timestamps 0 days 00:00:00.000500586
#
# Photometry
# CH1-410:
# 	first  1904-01-06 03:09:48.814600128
# 	last   1904-01-06 03:42:07.582796833
# 	length 0 days 00:32:18.768196705
# 	mean difference between timestamps 0 days 00:00:00.099988045
# CH1-470:
# 	first  1904-01-06 03:09:48.814600128
# 	last   1904-01-06 03:42:07.582796833
# 	length 0 days 00:32:18.768196705
# 	mean difference between timestamps 0 days 00:00:00.099988045
# CH1-560:
# 	first  1904-01-06 03:09:48.814600128
# 	last   1904-01-06 03:42:07.582796833
# 	length 0 days 00:32:18.768196705
# 	mean difference between timestamps 0 days 00:00:00.099988045
#
# Eye Movements
# Ellipse.Width:
# 	first  1904-01-06 03:10:00.965376
# 	last   1904-01-06 03:41:57.263360
# 	length 0 days 00:31:56.297984
# 	mean difference between timestamps 0 days 00:00:00.016666069
# Ellipse.Height:
# 	first  1904-01-06 03:10:00.965376
# 	last   1904-01-06 03:41:57.263360
# 	length 0 days 00:31:56.297984
# 	mean difference between timestamps 0 days 00:00:00.016666069
# Ellipse.Angle:
# 	first  1904-01-06 03:10:00.965376
# 	last   1904-01-06 03:41:57.263360
# 	length 0 days 00:31:56.297984
# 	mean difference between timestamps 0 days 00:00:00.016666069
# Ellipse.Center.X:
# 	first  1904-01-06 03:10:00.965376
# 	last   1904-01-06 03:41:57.263360
# 	length 0 days 00:31:56.297984
# 	mean difference between timestamps 0 days 00:00:00.016666069
# Ellipse.Center.Y:
# 	first  1904-01-06 03:10:00.965376
# 	last   1904-01-06 03:41:57.263360
# 	length 0 days 00:31:56.297984
# 	mean difference between timestamps 0 days 00:00:00.016666069
# Padding and resampling finished in 47.36 seconds.
# Global first timestamp: 1904-01-06 03:09:48.814600
# Global last timestamp: 1904-01-06 03:42:07.582700
# Global length: 0 days 00:32:18.768100
#
# H1
# OpticalTrackingRead0X(46):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# OpticalTrackingRead0Y(46):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# OpticalTrackingRead0Brightness(46):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# OpticalTrackingRead1X(46):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# OpticalTrackingRead1Y(46):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# OpticalTrackingRead1Brightness(46):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# Cam0Event(32):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# Cam1Event(33):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
#
# H2
# ImmediatePulses(42):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# AnalogInput(39):
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
#
# Photometry
# CH1-410:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# CH1-470:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# CH1-560:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
#
# Eye Movements
# Ellipse.Width:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# Ellipse.Height:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# Ellipse.Angle:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# Ellipse.Center.X:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100
# Ellipse.Center.Y:
# 	first  1904-01-06 03:09:48.814600
# 	last   1904-01-06 03:42:07.582700
# 	length 0 days 00:32:18.768100
# 	mean difference between timestamps 0 days 00:00:00.000100

# %%
Photometry
# Out:
#          TimeStamp Events  CH1-410  CH1-470  CH1-560  \
# 0            0.000    NaN   66.652  141.911   39.889
# 1          100.000    NaN   66.010  141.745   39.883
# 2          200.001    NaN   66.060  142.102   39.817
# 3          300.005    NaN   66.280  142.081   39.835
# 4          400.005    NaN   66.220  141.448   39.879
# ...            ...    ...      ...      ...      ...
# 19386  1938342.880    NaN   55.960  132.706   37.348
# 19387  1938442.863    NaN   56.377  132.897   37.418
# 19388  1938542.846    NaN   56.457  132.513   37.375
# 19389  1938642.834    NaN   56.376  132.817   37.450
# 19390  1938742.817    NaN   56.421  133.336   37.403
#
#                     HARP Timestamps
# 0     1904-01-06 03:09:48.814600128
# 1     1904-01-06 03:09:48.914601437
# 2     1904-01-06 03:09:49.014603746
# 3     1904-01-06 03:09:49.114609055
# 4     1904-01-06 03:09:49.214610364
# ...                             ...
# 19386 1904-01-06 03:42:07.182854597
# 19387 1904-01-06 03:42:07.282838906
# 19388 1904-01-06 03:42:07.382823215
# 19389 1904-01-06 03:42:07.482812524
# 19390 1904-01-06 03:42:07.582796833
#
# [19391 rows x 6 columns]

# %%
# Loading data
OnixAnalogClock = utils.read_OnixAnalogClock(data_path)
OnixAnalogData = utils.read_OnixAnalogData(data_path, binarise=True)
ExperimentEvents = utils.read_ExperimentEvents(data_path)

# Selecting desired HARP times, applying conversion to ONIX time
start_harp_time_of_halt_one = ExperimentEvents[ExperimentEvents.Value=='Apply halt: 1s'].iloc[0].Seconds
start_harp_time_of_halt_four = ExperimentEvents[ExperimentEvents.Value=='Apply halt: 1s'].iloc[3].Seconds

# Selecting photodiode times and data within the range, converting back to HARP and plotting
selected_harp_times, selected_photodiode_data = process.select_from_photodiode_data(OnixAnalogClock, OnixAnalogData, start_harp_time_of_halt_one - 1, start_harp_time_of_halt_four, conversions)

plt.plot(selected_harp_times, selected_photodiode_data[:, 0])
plt.show()
# Out:
# OnixAnalogClock loaded in 0.88 seconds.
# OnixAnalogData loaded in 2.51 seconds.
# Selection of photodiode data finished in 0.76 seconds.

# %% [markdown]
# ## Usage

# %%
running = resampled_streams['H1']['OpticalTrackingRead0X(46)']
rotation = resampled_streams['H1']['OpticalTrackingRead0Y(46)']
photometry = resampled_streams['Photometry']['CH1-470']
eye_movements = resampled_streams['Eye Movements']['Ellipse.Center.X']

# %%
def running_unit_conversion(running_array): #for ball linear movement
    resolution = 12000 # counts per inch
    inches_per_count = 1 / resolution
    meters_per_count = 0.0254 * inches_per_count
    dt = 0.01 # for OpticalTrackingRead0Y(46) -this is sensor specific. current sensor samples at 100 hz 
    linear_velocity = meters_per_count / dt # meters per second per count
    
    return running_array * linear_velocity

# %%
def rotation_unit_conversion(rotation_array): # for ball rotation
    resolution = 12000 # counts per inch
    inches_per_count = 1 / resolution
    meters_per_count = 0.0254 * inches_per_count
    dt = 0.01 # for OpticalTrackingRead0Y(46) -this is sensor specific. current sensor samples at 100 hz 
    linear_velocity = meters_per_count / dt # meters per second per count
    
    ball_radius = 0.1 # meters 
    angular_velocity = linear_velocity / ball_radius # radians per second per count
    angular_velocity = angular_velocity * (180 / np.pi) # degrees per second per count
    
    return rotation_array * angular_velocity

# %%
running = running_unit_conversion(running) # meters per second
running *= 100 # centimeters per second

# %%
rotation = rotation_unit_conversion(rotation) # degrees per second
# Out:
# 0.12127606663602424

# %%
#pupil_diameter = elipse.hight + elipse.width /2

# %%
#A = None #time window beginning in harp seconds, min different from dataset to dataset, None means from start
#B = None #time window end in harp seconds, None means to end 
A = 444100 
B = A + 50

photodiode_x, photodiode_y = process.select_from_photodiode_data(OnixAnalogClock, OnixAnalogData, A, B, conversions)

fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(12,24))

t = (running.index - utils.harp.REFERENCE_EPOCH).total_seconds() #date stamp to seconds 

ax[0].plot(t, running)
ax[0].set_title('Running')
ax[0].set_xlim([A,B])
ax[0].set_xlabel('time (seconds)')
ax[0].set_ylabel('running speed (cm/s)')

ax[1].plot(t, photometry)
ax[1].set_title('CH1-470')
ax[1].set_xlim([A,B])
ax[1].set_xlabel('time (seconds)')
ax[1].set_ylabel('signal magnitude')

ax[2].plot(t, eye_movements)
ax[2].set_title('Eye Movements')
ax[2].set_xlim([A,B])
ax[2].set_xlabel('time (seconds)')
ax[2].set_ylabel('horizontal eye position (pixels)')

ax[3].plot(process.convert_datetime_to_seconds(photodiode_x), photodiode_y[:,0])
ax[3].set_title('Photodiode')
ax[3].set_xlim([A,B])
ax[3].set_xlabel('time (seconds)')
ax[3].set_ylabel('photodiode signal')

plt.show()
# Out:
# Selection of photodiode data finished in 2.37 seconds.

# %%
# save resampled data as CSV with header, have a column with time  
# on top of registers, save running (cm/s) and rotation (deg/s) as well as pupil_diameter (px)
#process.save_streams_to_excel('/home/ikharitonov/Desktop/export_test.xlsx', resampled_streams)

# %%
resampled_streams
# Out:
# {'H1': {'OpticalTrackingRead0X(46)': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000754
#   1904-01-06 03:09:48.814800    0.001509
#   1904-01-06 03:09:48.814900    0.002263
#   1904-01-06 03:09:48.815000    0.003018
#                                   ...
#   1904-01-06 03:42:07.582300    0.004092
#   1904-01-06 03:42:07.582400    0.003069
#   1904-01-06 03:42:07.582500    0.002046
#   1904-01-06 03:42:07.582600    0.001023
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'OpticalTrackingRead0Y(46)': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000008
#   1904-01-06 03:09:48.814800    0.000016
#   1904-01-06 03:09:48.814900    0.000024
#   1904-01-06 03:09:48.815000    0.000031
#                                   ...
#   1904-01-06 03:42:07.582300    0.000162
#   1904-01-06 03:42:07.582400    0.000122
#   1904-01-06 03:42:07.582500    0.000081
#   1904-01-06 03:42:07.582600    0.000041
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'OpticalTrackingRead0Brightness(46)': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000471
#   1904-01-06 03:09:48.814800    0.000943
#   1904-01-06 03:09:48.814900    0.001414
#   1904-01-06 03:09:48.815000    0.001886
#                                   ...
#   1904-01-06 03:42:07.582300    0.002026
#   1904-01-06 03:42:07.582400    0.001519
#   1904-01-06 03:42:07.582500    0.001013
#   1904-01-06 03:42:07.582600    0.000506
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'OpticalTrackingRead1X(46)': 1904-01-06 03:09:48.814600    0.0
#   1904-01-06 03:09:48.814700    0.0
#   1904-01-06 03:09:48.814800    0.0
#   1904-01-06 03:09:48.814900    0.0
#   1904-01-06 03:09:48.815000    0.0
#                                ...
#   1904-01-06 03:42:07.582300    0.0
#   1904-01-06 03:42:07.582400    0.0
#   1904-01-06 03:42:07.582500    0.0
#   1904-01-06 03:42:07.582600    0.0
#   1904-01-06 03:42:07.582700    0.0
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'OpticalTrackingRead1Y(46)': 1904-01-06 03:09:48.814600    0.0
#   1904-01-06 03:09:48.814700    0.0
#   1904-01-06 03:09:48.814800    0.0
#   1904-01-06 03:09:48.814900    0.0
#   1904-01-06 03:09:48.815000    0.0
#                                ...
#   1904-01-06 03:42:07.582300    0.0
#   1904-01-06 03:42:07.582400    0.0
#   1904-01-06 03:42:07.582500    0.0
#   1904-01-06 03:42:07.582600    0.0
#   1904-01-06 03:42:07.582700    0.0
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'OpticalTrackingRead1Brightness(46)': 1904-01-06 03:09:48.814600    0.0
#   1904-01-06 03:09:48.814700    0.0
#   1904-01-06 03:09:48.814800    0.0
#   1904-01-06 03:09:48.814900    0.0
#   1904-01-06 03:09:48.815000    0.0
#                                ...
#   1904-01-06 03:42:07.582300    0.0
#   1904-01-06 03:42:07.582400    0.0
#   1904-01-06 03:42:07.582500    0.0
#   1904-01-06 03:42:07.582600    0.0
#   1904-01-06 03:42:07.582700    0.0
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'Cam0Event(32)':                               0  Cam0Event
#   1904-01-06 03:09:48.814600  0.0        NaN
#   1904-01-06 03:09:48.814700  0.0        NaN
#   1904-01-06 03:09:48.814800  0.0        NaN
#   1904-01-06 03:09:48.814900  0.0        NaN
#   1904-01-06 03:09:48.815000  0.0        NaN
#   ...                         ...        ...
#   1904-01-06 03:42:07.582300  0.0        1.0
#   1904-01-06 03:42:07.582400  0.0        1.0
#   1904-01-06 03:42:07.582500  0.0        1.0
#   1904-01-06 03:42:07.582600  0.0        1.0
#   1904-01-06 03:42:07.582700  0.0        1.0
#
#   [19387682 rows x 2 columns],
#   'Cam1Event(33)':                               0  Cam1Event
#   1904-01-06 03:09:48.814600  0.0        NaN
#   1904-01-06 03:09:48.814700  0.0        NaN
#   1904-01-06 03:09:48.814800  0.0        NaN
#   1904-01-06 03:09:48.814900  0.0        NaN
#   1904-01-06 03:09:48.815000  0.0        NaN
#   ...                         ...        ...
#   1904-01-06 03:42:07.582300  0.0        1.0
#   1904-01-06 03:42:07.582400  0.0        1.0
#   1904-01-06 03:42:07.582500  0.0        1.0
#   1904-01-06 03:42:07.582600  0.0        1.0
#   1904-01-06 03:42:07.582700  0.0        1.0
#
#   [19387682 rows x 2 columns]},
#  'H2': {'ImmediatePulses(42)': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000891
#   1904-01-06 03:09:48.814800    0.001782
#   1904-01-06 03:09:48.814900    0.002674
#   1904-01-06 03:09:48.815000    0.003565
#                                   ...
#   1904-01-06 03:42:07.582300    0.000000
#   1904-01-06 03:42:07.582400    0.000000
#   1904-01-06 03:42:07.582500    0.000000
#   1904-01-06 03:42:07.582600    0.000000
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'AnalogInput(39)': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000283
#   1904-01-06 03:09:48.814800    0.000566
#   1904-01-06 03:09:48.814900    0.000849
#   1904-01-06 03:09:48.815000    0.001132
#                                   ...
#   1904-01-06 03:42:07.582300    0.001399
#   1904-01-06 03:42:07.582400    0.001050
#   1904-01-06 03:42:07.582500    0.000700
#   1904-01-06 03:42:07.582600    0.000350
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64},
#  'Photometry': {'CH1-410': HARP Timestamps
#   1904-01-06 03:09:48.814600    66.652000
#   1904-01-06 03:09:48.814700    66.651358
#   1904-01-06 03:09:48.814800    66.650716
#   1904-01-06 03:09:48.814900    66.650074
#   1904-01-06 03:09:48.815000    66.649432
#                                   ...
#   1904-01-06 03:42:07.582300    56.420820
#   1904-01-06 03:42:07.582400    56.420865
#   1904-01-06 03:42:07.582500    56.420910
#   1904-01-06 03:42:07.582600    56.420955
#   1904-01-06 03:42:07.582700    56.421000
#   Freq: 100us, Name: CH1-410, Length: 19387682, dtype: float64,
#   'CH1-470': HARP Timestamps
#   1904-01-06 03:09:48.814600    141.911000
#   1904-01-06 03:09:48.814700    141.910834
#   1904-01-06 03:09:48.814800    141.910668
#   1904-01-06 03:09:48.814900    141.910502
#   1904-01-06 03:09:48.815000    141.910336
#                                    ...
#   1904-01-06 03:42:07.582300    133.333922
#   1904-01-06 03:42:07.582400    133.334441
#   1904-01-06 03:42:07.582500    133.334961
#   1904-01-06 03:42:07.582600    133.335480
#   1904-01-06 03:42:07.582700    133.336000
#   Freq: 100us, Name: CH1-470, Length: 19387682, dtype: float64,
#   'CH1-560': HARP Timestamps
#   1904-01-06 03:09:48.814600    39.889000
#   1904-01-06 03:09:48.814700    39.888994
#   1904-01-06 03:09:48.814800    39.888988
#   1904-01-06 03:09:48.814900    39.888982
#   1904-01-06 03:09:48.815000    39.888976
#                                   ...
#   1904-01-06 03:42:07.582300    37.403188
#   1904-01-06 03:42:07.582400    37.403141
#   1904-01-06 03:42:07.582500    37.403094
#   1904-01-06 03:42:07.582600    37.403047
#   1904-01-06 03:42:07.582700    37.403000
#   Freq: 100us, Name: CH1-560, Length: 19387682, dtype: float64},
#  'Eye Movements': {'Ellipse.Width': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000197
#   1904-01-06 03:09:48.814800    0.000394
#   1904-01-06 03:09:48.814900    0.000591
#   1904-01-06 03:09:48.815000    0.000788
#                                   ...
#   1904-01-06 03:42:07.582300    0.000949
#   1904-01-06 03:42:07.582400    0.000712
#   1904-01-06 03:42:07.582500    0.000475
#   1904-01-06 03:42:07.582600    0.000237
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'Ellipse.Height': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000182
#   1904-01-06 03:09:48.814800    0.000364
#   1904-01-06 03:09:48.814900    0.000546
#   1904-01-06 03:09:48.815000    0.000727
#                                   ...
#   1904-01-06 03:42:07.582300    0.000901
#   1904-01-06 03:42:07.582400    0.000676
#   1904-01-06 03:42:07.582500    0.000451
#   1904-01-06 03:42:07.582600    0.000225
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'Ellipse.Angle': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700    0.000014
#   1904-01-06 03:09:48.814800    0.000028
#   1904-01-06 03:09:48.814900    0.000042
#   1904-01-06 03:09:48.815000    0.000056
#                                   ...
#   1904-01-06 03:42:07.582300   -0.000026
#   1904-01-06 03:42:07.582400   -0.000020
#   1904-01-06 03:42:07.582500   -0.000013
#   1904-01-06 03:42:07.582600   -0.000007
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'Ellipse.Center.X': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700   -0.000011
#   1904-01-06 03:09:48.814800   -0.000023
#   1904-01-06 03:09:48.814900   -0.000034
#   1904-01-06 03:09:48.815000   -0.000046
#                                   ...
#   1904-01-06 03:42:07.582300   -0.000497
#   1904-01-06 03:42:07.582400   -0.000373
#   1904-01-06 03:42:07.582500   -0.000249
#   1904-01-06 03:42:07.582600   -0.000124
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64,
#   'Ellipse.Center.Y': 1904-01-06 03:09:48.814600    0.000000
#   1904-01-06 03:09:48.814700   -0.000047
#   1904-01-06 03:09:48.814800   -0.000095
#   1904-01-06 03:09:48.814900   -0.000142
#   1904-01-06 03:09:48.815000   -0.000190
#                                   ...
#   1904-01-06 03:42:07.582300   -0.000307
#   1904-01-06 03:42:07.582400   -0.000230
#   1904-01-06 03:42:07.582500   -0.000153
#   1904-01-06 03:42:07.582600   -0.000077
#   1904-01-06 03:42:07.582700    0.000000
#   Freq: 100us, Length: 19387682, dtype: float64}}
